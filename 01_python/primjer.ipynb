# %% [markdown]
# # Primjer Jupyter Notebooka
#
# Ovo je primjer Jupyter Notebooka koji se automatski generira unutar Jupyter Book web stranice. Možete koristiti Markdown ćelije za pisanje teksta, a Python ćelije za izvršavanje koda.

# %%
print("Dobro došli i sretno učenje!")
# Out:
# Dobro došli i sretno učenje!
